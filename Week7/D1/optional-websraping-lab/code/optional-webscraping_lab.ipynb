# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm.notebook import tqdm
# from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
# from urllib.request import urlopen
# import random
# import re
# import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://github.githubassets.com" rel="dns-prefetch"/>
#   <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
#   <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
#   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-eca8e21af2622cbcba2c93c67f79baed.css" integrity="sha512-7KjiGvJiLLy6LJPGf3m67ejAdgQsgDdnxZYoaI6+Agd0ZxHKTCjoKZgaf3PgUjURCcVceAwySJJJWgitRskDiA==" media="all" rel="stylesheet">
#    <link crossorigin="anonymous" href="https://github.githubassets.com/assets/behaviors-f1bee898f94fff2126806c33b72d3b50.css" integrity="sha512-8b7omPlP/yEmgGwzty07UCWwxjJLdNp3WAiXPEnS7mZvEvNKdiuLXT681i7qJujik30dRviXyNkKAz9F4w94UA==" media="all" rel="stylesheet">
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names (OPTIONAL plus handles).
#
# 1. Use string manipulation techniques as needed. Use a list to store the clean names and handles.
#
# 1. Print the list of names.
#
# Your output should look like the below:
#
# ```
# ['Name (handle)',
#  'Name (handle)']
#  ```
#  for example
#
#  ```
# ['Henrik Rydgard (hrydgard)',
#  'Tim Holy (timholy)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)']
#  ```

# %%
soup.select("article")[49]
# Out:
# <article>
# <div class="f6 color-text-secondary text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M7.998 14.5c2.832 0 5-1.98 5-4.5 0-1.463-.68-2.19-1.879-3.383l-.036-.037c-1.013-1.008-2.3-2.29-2.834-4.434-.322.256-.63.579-.864.953-.432.696-.621 1.58-.046 2.73.473.947.67 2.284-.278 3.232-.61.61-1.545.84-2.403.633a2.788 2.788 0 01-1.436-.874A3.21 3.21 0 003 10c0 2.53 2.164 4.5 4.998 4.5zM9.533.753C9.496.34 9.16.009 8.77.146 7.035.75 4.34 3.187 5.997 6.5c.344.689.285 1.218.003 1.5-.419.419-1.54.487-2.04-.832-.173-.454-.659-.762-1.035-.454C2.036 7.44 1.5 8.702 1.5 10c0 3.512 2.998 6 6.498 6s6.5-2.5 6.5-6c0-2.137-1.128-3.26-2.312-4.438-1.19-1.184-2.436-2.425-2.653-4.81z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# ...

# %%
soup.select("article")[0].select("a")[2]['href'].replace("/","")
# Out:
# 'casey'

# %%
soup.select("article")[0].select("a")[2].text.replace("\n","").strip()
# Out:
# 'Casey Rodarmor'

# %%
names = []
for i in tqdm(range(0,len(soup.select("article")),2)):
    a = soup.select("article")[i].select("a")[2].text.replace("\n","").strip()
    b = soup.select("article")[i].select("a")[2]['href'].replace("/","")
    names.append(a+" ("+b+")")
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
names
# Out:
# ['Casey Rodarmor (casey)',
#  'Saleem Abdulrasool (compnerd)',
#  'cytopia (cytopia)',
#  'Chris Banes (chrisbanes)',
#  'Franck Nijhof (frenck)',
#  'andig (andig)',
#  'Thomas Lovén (thomasloven)',
#  'Andrew Gallant (BurntSushi)',
#  'An Tao (an-tao)',
#  'Walter Huf (hufman)',
#  'Jakub Jareš (nohwnd)',
#  'Yusuke Kuoka (mumoshu)',
#  'Anna Henningsen (addaleax)',
#  'Fons van der Plas (fonsp)',
#  'vn.py (vnpy)',
#  'Alexander Grebenyuk (kean)',
#  'Kévin Dunglas (dunglas)',
#  'vincent d warmerdam (koaning)',
#  'Ben Rogerson (ben-rogerson)',
#  'Radovan Bast (bast)',
#  'chrisleekr (chrisleekr)',
#  'Ben Frederickson (benfred)',
#  'Gal Schlezinger (Schniz)',
#  'Diego Muracciole (diegomura)',
#  'Zoltan Kochan (zkochan)']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names- and you will need to employ string functions to remove unnecessary characters and spaces.
#
# Your output should look like the below:
#
# ```
# ['EricJMarti/ inventory-hunter',
#  'python-telegram-bot/ python-telegram-bot',
#  'huggingface/ datasets',
#  'jiupinjia/ stylized-neural-painting',
#  'swisskyrepo/ PayloadsAllTheThings',
#  'Bitwise-01/ Instagram-']
#  ```

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://github.githubassets.com" rel="dns-prefetch"/>
#   <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
#   <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
#   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-eca8e21af2622cbcba2c93c67f79baed.css" integrity="sha512-7KjiGvJiLLy6LJPGf3m67ejAdgQsgDdnxZYoaI6+Agd0ZxHKTCjoKZgaf3PgUjURCcVceAwySJJJWgitRskDiA==" media="all" rel="stylesheet">
#    <link crossorigin="anonymous" href="https://github.githubassets.com/assets/behaviors-f1bee898f94fff2126806c33b72d3b50.css" integrity="sha512-8b7omPlP/yEmgGwzty07UCWwxjJLdNp3WAiXPEnS7mZvEvNKdiuLXT681i7qJujik30dRviXyNkKAz9F4w94UA==" media="all" rel="stylesheet">
# ...

# %% [markdown]
# Finding the data:

# %%
soup.select("article")[0].select("a")[1]['href']
# Out:
# '/facebookresearch/dino'

# %%
gitl="https://github.com"
iterations = len(soup.select("article"))

# %% [markdown]
# We can make it as a list comprehension:

# %%
[gitl+soup.select("article")[i].select("a")[1]['href'] for i in range(iterations)]
# Out:
# ['https://github.com/facebookresearch/dino',
#  'https://github.com/Chia-Network/chia-blockchain',
#  'https://github.com/DIGITALCRIMINAL/OnlyFans',
#  'https://github.com/twintproject/twint',
#  'https://github.com/nvbn/thefuck',
#  'https://github.com/home-assistant/core',
#  'https://github.com/Datalux/Osintgram',
#  'https://github.com/521xueweihan/HelloGitHub',
#  'https://github.com/edeng23/binance-trade-bot',
#  'https://github.com/ytdl-org/youtube-dl',
#  'https://github.com/swar/Swar-Chia-Plot-Manager',
#  'https://github.com/Binance-docs/Binance_Futures_python',
#  'https://github.com/OWASP/CheatSheetSeries',
#  'https://github.com/pallupz/covid-vaccine-booking',
#  'https://github.com/breakdowns/slam-mirrorbot',
#  'https://github.com/huggingface/datasets',
#  'https://github.com/facebookresearch/suncet',
#  'https://github.com/freqtrade/freqtrade-strategies',
#  'https://github.com/ml-tooling/best-of-ml-python',
#  'https://github.com/ManimCommunity/manim',
# ...

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Walt Disney - Wikipedia
#   </title>
#   <script>
# ...

# %%
images = []
for image in soup.find_all('img'):
    if image['src']!=0:
        images.append("http:"+image['src'])

# %%
images
# Out:
# ['http://upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png',
#  'http://upload.wikimedia.org/wikipedia/en/thumb/8/8c/Extended-protection-shackle.svg/20px-Extended-protection-shackle.svg.png',
#  'http://upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  'http://upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  'http://upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  'http://upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Newman_Laugh-O-Gram_%281921%29.webm/220px-seek%3D2-Newman_Laugh-O-Gram_%281921%29.webm.jpg',
#  'http://upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python' 
response = requests.get(url)
print(response.status_code)
soup = BeautifulSoup(response.content,'html.parser')
print(soup.prettify())
# Out:
# 200
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Python - Wikipedia
#   </title>
#   <script>
# ...

# %%
soup.select(".mw-parser-output > ul:nth-child(9) > li:nth-child(4)")
# Out:
# [<li><a href="/wiki/Python_of_Catana" title="Python of Catana">Python of Catana</a>, poet who accompanied Alexander the Great</li>]

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
#your code

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
#your code

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
#your code

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
#your code

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your code

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
#your code

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
