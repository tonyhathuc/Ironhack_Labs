# %% [markdown]
# # Lab | API wrappers - Create your collection of songs & audio features

# %% [markdown]
# * Take audio features of the input song and compare to audio features from spotify API
# * Build a model that can compare the audio features of input and our df and recommend a song with similar features
#
# * Lab Wednesday to build the df with maaaaaany songs and their audiofeatures, that we can use in the above to recommend a song

# %% [markdown]
# * build a loop with loops to get all song ids of all playlists of desired cat
#
# * get cat id
# * get all playlists under cat
# * get all playlist ids
# * get all songs under playlists
# * get all song ids
# * get all audiofeatures for all song ids
#
# * this can be used to get all the audio features from all songs

# %%
# will still import fundamental libraries for DA
import numpy as np
import pandas as pd 
import matplotlib

# %%
Client ID 7b18135698b64fc1a318a0e688ec8eec

Client Secret 12df486c28dd44f7a3dbb6435e67afeb
# Out:
#   File "<ipython-input-2-9c1c80e6e27f>", line 1
#     Client ID 7b18135698b64fc1a318a0e688ec8eec
#            ^
# SyntaxError: invalid syntax

# %%
import getpass
client_id = getpass.getpass('client_id?')
client_secret = getpass.getpass('client_secret?')
# Out:
# client_id?········
# client_secret?········

# %%
# import Spotipy (a lightweight Python library for the Spotify Web API)
# with Spotipy you get full access to all of the music data provided by the Spotify platform

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# create API connection in a variable 
# needs to be given our credentials

# connect to the API
# the API connection will be stored in "sp" variable
# we need to give our credentials 

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id ,
                                                           client_secret=client_secret))

# %%
# using sp.categories() from spotipy to get categorie IDs

cat_all = sp.categories(country=None, locale=None, limit=50, offset=0)
cat_all
# Out:
# {'categories': {'href': 'https://api.spotify.com/v1/browse/categories?offset=0&limit=50',
#   'items': [{'href': 'https://api.spotify.com/v1/browse/categories/toplists',
#     'icons': [{'height': 275,
#       'url': 'https://t.scdn.co/media/derived/toplists_11160599e6a04ac5d6f2757f5511778f_0_0_275_275.jpg',
#       'width': 275}],
#     'id': 'toplists',
#     'name': 'Top Lists'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/pop',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/pop-274x274_447148649685019f5e2a03a39e78ba52_0_0_274_274.jpg',
#       'width': 274}],
#     'id': 'pop',
#     'name': 'Pop'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/hiphop',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/original/hip-274_0a661854d61e29eace5fe63f73495e68_274x274.jpg',
#       'width': 274}],
#     'id': 'hiphop',
#     'name': 'Hip Hop'},
# ...

# %%
cat_all.keys()
# Out:
# dict_keys(['categories'])

# %%
cat_all['categories'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
cat_all['categories']['items'][0].keys()
# Out:
# dict_keys(['href', 'icons', 'id', 'name'])

# %%
# here we have the name of the cat

cat_all['categories']['items'][2]['name']
# Out:
# 'Pop'

# %%
# here we have the id of the cat

cat_all['categories']['items'][2]['id']
# Out:
# 'pop'

# %%
# now lets get a list of all the cat ids

cat_ids = []

len_cat_all = len(cat_all['categories']['items'])

for i in range(len_cat_all):
    cat_ids.append(cat_all['categories']['items'][i]['id'])
print(cat_ids)
# Out:
# ['toplists', 'pop', 'hiphop', 'equal', 'mood', 'indie_alt', 'edm_dance', 'workout', 'rock', 'latin', 'summer', 'sanremo_2021', 'decades', 'radar', 'gaming', 'chill', 'at_home', 'party', 'focus', 'jazz', 'romance', 'student', 'classical', 'alternative', 'rnb', 'wellness', 'kids_family', 'popculture', 'travel', 'sleep', 'dinner', 'kpop', 'metal', 'soul', 'blues', 'funk', 'roots', 'punk', 'instrumental', 'caribbean', 'flamenco', 'thirdparty']

# %%
cat_ids_new = ['toplists', 'pop', 'hiphop', 'equal', 'mood', 'indie_alt', 'edm_dance', 'workout', 'rock', 'latin', 'summer']

# %%
playlist_ids = []
for cat in cat_ids_new:
    playlist_ids.append([item['id'] for item in sp.category_playlists(category_id='cat')['playlists']['items']])
# Out:
# 2021-05-05 17:08:41,465 [14273] ERROR    spotipy.client:258: [JupyterRequire] HTTP Error for GET to https://api.spotify.com/v1/browse/categories/cat/playlists returned 404 due to Specified id doesn't exist
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     244
# --> 245             response.raise_for_status()
#     246             results = response.json()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/browse/categories/cat/playlists?limit=20&offset=0
#
# During handling of the above exception, another exception occurred:
# ...

# %%
[item['id'] for item in sp.category_playlists(category_id='hiphop', limit =50)['playlists']['items']]
# Out:
# ['37i9dQZF1DX0XUsuxWHRQd',
#  '37i9dQZF1DX2RxBh64BHjQ',
#  '37i9dQZF1DX2A29LI7xHn1',
#  '37i9dQZF1DWVA1Gq4XHa6U',
#  '37i9dQZF1DX9oh43oAzkyx',
#  '37i9dQZF1DX6GwdWRQMQpq',
#  '37i9dQZF1DWYok9l1JL7GM',
#  '37i9dQZF1DWTplaZ1W7ARf',
#  '37i9dQZF1DX2XmsXL2WBQd',
#  '37i9dQZF1DX3KoYiZJ8DD4',
#  '37i9dQZF1DWWAqc46ZJdZf']

# %%
playlist_ids
# Out:
# []

# %%
# We will use the pop cat for our database

# now we will use category_playlists() to get all the playlists from the cat pop

pop_playlists = sp.category_playlists(category_id='pop')
pop_playlists
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/browse/categories/pop/playlists?offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': 'Billie Eilish is on top of the Hottest 50!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcBWIGoYBM5M'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M',
#     'id': '37i9dQZF1DXcBWIGoYBM5M',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000398acdce7d57c6242e76d33a4',
#       'width': None}],
#     'name': "Today's Top Hits",
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
# ...

# %%
funk_playlists = sp.category_playlists(category_id='funk')
funk_playlists

[item['id'] for item in sp.category_playlists(category_id='summer')['playlists']['items']]
# Out:
# ['37i9dQZF1DWZKxDdpAkEjR',
#  '37i9dQZF1DWSf2RDTDayIx',
#  '37i9dQZF1DXb54TOYHv7Df',
#  '37i9dQZF1DWYAcBZSAVhlf',
#  '37i9dQZF1DX83I5je4W4rP',
#  '37i9dQZF1DWZg863fGtALu',
#  '37i9dQZF1DX5Ozry5U6G0d',
#  '37i9dQZF1DX6aqIZNmXBGU',
#  '37i9dQZF1DX4psg7TSYpot',
#  '37i9dQZF1DX6ALfRKlHn1t',
#  '37i9dQZF1DWWsGacA3f5kN',
#  '37i9dQZF1DXbHKTQ2s1l8q',
#  '37i9dQZF1DWZSdcRHMl2tT',
#  '37i9dQZF1DWTKxc7ZObqeH',
#  '37i9dQZF1DXbwoaqxaoAVr',
#  '37i9dQZF1DWVAArCxuIRGQ',
#  '37i9dQZF1DWUajed02NzWR',
#  '37i9dQZF1DXa8n42306eJB',
#  '37i9dQZF1DX44AF5xq04Oh',
#  '37i9dQZF1DWYRUctuBGBo1']

# %%
[item['id'] for item in sp.category_playlists(category_id='summer')['playlists']['items']]
[item['owner']['id'] for item in sp.category_playlists(category_id='summer')['playlists']['items']]

# %%
summer_playlists = [item['id'] for item in sp.category_playlists(category_id='summer')['playlists']['items']]
summer_playlists
# Out:
# ['37i9dQZF1DWZKxDdpAkEjR',
#  '37i9dQZF1DWSf2RDTDayIx',
#  '37i9dQZF1DXb54TOYHv7Df',
#  '37i9dQZF1DWYAcBZSAVhlf',
#  '37i9dQZF1DX83I5je4W4rP',
#  '37i9dQZF1DWZg863fGtALu',
#  '37i9dQZF1DX5Ozry5U6G0d',
#  '37i9dQZF1DX6aqIZNmXBGU',
#  '37i9dQZF1DX4psg7TSYpot',
#  '37i9dQZF1DX6ALfRKlHn1t',
#  '37i9dQZF1DWWsGacA3f5kN',
#  '37i9dQZF1DXbHKTQ2s1l8q',
#  '37i9dQZF1DWZSdcRHMl2tT',
#  '37i9dQZF1DWTKxc7ZObqeH',
#  '37i9dQZF1DXbwoaqxaoAVr',
#  '37i9dQZF1DWVAArCxuIRGQ',
#  '37i9dQZF1DWUajed02NzWR',
#  '37i9dQZF1DXa8n42306eJB',
#  '37i9dQZF1DX44AF5xq04Oh',
#  '37i9dQZF1DWYRUctuBGBo1']

# %%
for x in cat_ids_new:
    print(x, len([item['id'] for item in sp.category_playlists(category_id=x)['playlists']['items']]))
# Out:
# toplists 14
# pop 2
# hiphop 11
# equal 20
# mood 6
# indie_alt 11
# edm_dance 17
# workout 19
# rock 18
# latin 20
# summer 20

# %%
pop_playlists.keys()
# Out:
# dict_keys(['playlists'])

# %%
pop_playlists['playlists'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
pop_playlists['playlists']['items'][0].keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %%
# here we have the playlist id

pop_playlists['playlists']['items'][0]['id']
# Out:
# '37i9dQZF1DXcBWIGoYBM5M'

# %%
# here we have the playlist name

pop_playlists['playlists']['items'][1]['name']
# Out:
# 'spotify'

# %%
# for the next step we need also the owner of the playlist

# here we have it

pop_playlists['playlists']['items'][0]['owner']['id']
# Out:
# 'spotify'

# %%
# now lets get a list of all the playlist ids from the pop cat

pop_playlist_ids = []
pop_playlist_owners = []

len_pop_playlists = len(pop_playlists['playlists']['items'])

for i in range(len_pop_playlists):
    pop_playlist_ids.append(pop_playlists['playlists']['items'][i]['id'])
    print(pop_playlist_ids)
    pop_playlist_owners.append(pop_playlists['playlists']['items'][i]['owner']['id'])
# Out:
# ['37i9dQZF1DXcBWIGoYBM5M']
# ['37i9dQZF1DXcBWIGoYBM5M', '37i9dQZF1DWUa8ZRTfalHk']

# %%
def playlist_dic(playlist_lst):
    for cat in 
        playlist_ids = [item['id'] for item in sp.category_playlists(category_id='summer')['playlists']['items']]
        playlist_owners = [item['owner']['id'] for item in sp.category_playlists(category_id='summer')['playlists']['items']]
        playlist_dic = dict(zip(playlist_owners, playlist_ids))
        return playlist_dic

# %%
def playlist_dic(playlist_lst):
    playlist_ids = [item['id'] for item in sp.category_playlists(category_id='summer')['playlists']['items']]
    playlist_owners = [item['owner']['id'] for item in sp.category_playlists(category_id='summer')['playlists']['items']]
    playlist_dic = dict(zip(playlist_owners, playlist_ids))
    return playlist_dic

# %%
[item['owner']['id'] for item in sp.category_playlists(category_id='summer')['playlists']['items']]
# Out:
# ['spotify',
#  'spotify',
#  'spotify',
#  'spotify',
#  'spotify',
#  'spotify',
#  'spotify',
#  'spotify',
#  'spotify',
#  'spotify',
#  'spotify',
#  'spotify',
#  'spotify',
#  'spotify',
#  'spotify',
#  'spotify',
#  'spotify',
#  'spotify',
#  'spotify',
#  'spotify']

# %%
playlist_dic(summer_playlists)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-244-8a343d9548ee> in <module>
#       1 playlist_dic(summer_playlists)
# ----> 2 playlist_owners
#
# NameError: name 'playlist_owners' is not defined

# %%
playlist_owners
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-243-8eb9c12b091a> in <module>
# ----> 1 playlist_owners
#
# NameError: name 'playlist_owners' is not defined

# %%
def get_track_ids_from_playlist_dics(playlist_dic):
    ids = []
    for owner, id_ in enumerate(playlist_dic):
        ids += get_track_ids(sp.user_playlist_tracks(owner, id_))
    return ids

# %%
pop_playlist_dic
# Out:
# {'37i9dQZF1DXcBWIGoYBM5M': 'spotify', '37i9dQZF1DWUa8ZRTfalHk': 'spotify'}

# %%
get_track_ids_from_playlist_dics(playlist_dic(summer_playlists))
# Out:
# 2021-05-05 17:45:16,705 [14273] ERROR    spotipy.client:258: [JupyterRequire] HTTP Error for GET to https://api.spotify.com/v1/playlists/spotify/tracks returned 404 due to Invalid playlist Id
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     244
# --> 245             response.raise_for_status()
#     246             results = response.json()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/playlists/spotify/tracks?limit=100&offset=0&additional_types=track
#
# ...

# %%
# hm this is only 2 playlists ...

pop_playlist_ids
# Out:
# ['37i9dQZF1DXcBWIGoYBM5M', '37i9dQZF1DWUa8ZRTfalHk']

# %%
pop_playlist_owners
# Out:
# ['spotify', 'spotify']

# %%
# lets put them together in a dic

pop_playlist_dic = dict(zip(pop_playlist_ids, pop_playlist_owners))
pop_playlist_dic
# Out:
# {'37i9dQZF1DXcBWIGoYBM5M': 'spotify', '37i9dQZF1DWUa8ZRTfalHk': 'spotify'}

# %%
summer_playlists_dic =

# %%
def get_tracks(playlist_id, owner):
    tracks = []
    tracks.append(sp.user_playlist_tracks(value, key))

# %%
# We will use the 2 found pop playists to get tracks

# thererfor we will use sp.user_playlist_tracks() to get all the tracks from the pop playlists

tracks = []

for value, key in enumerate(pop_playlist_dic):
    tracks.append(sp.user_playlist_tracks(value, key))

# %%
# as tracks is a list, I have to access the 2 playlists

tracks[1].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
tracks[1]
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWUa8ZRTfalHk/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2021-04-30T04:00:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TIYQ3jFPwQSRmorSezPxX'},
#        'href': 'https://api.spotify.com/v1/artists/6TIYQ3jFPwQSRmorSezPxX',
#        'id': '6TIYQ3jFPwQSRmorSezPxX',
#        'name': 'Machine Gun Kelly',
#        'type': 'artist',
#        'uri': 'spotify:artist:6TIYQ3jFPwQSRmorSezPxX'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3M9XAM57a4qFz3v6Lq27t2'},
# ...

# %%
tracks[1]['items'][5]['track']['id']
# Out:
# '3ydI3CesHBnaY01Qff9jOr'

# %%
playlist = sp.user_playlist_tracks('spotify', '37i9dQZF1DXcBWIGoYBM5M')
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2021-05-03T15:49:35Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
# ...

# %%
# function für 1 playlist
# return wert alle track ids

def get_track_ids(playlist):
    track_ids = []

    for item in playlist['items']:
        track_ids.append((item['track']['id']))
    return track_ids

# %%
# function using the function above to get 

def get_track_ids_from_playlist_dics(playlist_dic):
    ids = []
    for id_, owner in enumerate(playlist_dic):
        ids += get_track_ids(sp.user_playlist_tracks(id_, owner))
    return ids
# Out:
# 100

# %%
get_track_ids_from_playlist_dics(pop_playlist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-250-473d44b62734> in <module>
# ----> 1 get_track_ids_from_playlist_dics(pop_playlist)
#
# NameError: name 'pop_playlist' is not defined

# %%
tracks = get_track_ids(playlist_dic(summer_playlists))

# %% [markdown]
# def get_track_ids(x):
#
#     playlist = []
#     for value, key in enumerate(playlist_dic):
#         playlist.append(sp.user_playlist_tracks(value, key))
#
#         track_ids = []
#         for item in playlist['items']:
#             track_ids.append((item['track']['id']))
#         return track_ids

# %% [markdown]
# # function to get playlists
#
# def get_playlists:
#     playlist = []
#
#     for value, key in enumerate(playlist_dic):
#         playlist.append(sp.user_playlist_tracks(value, key))

# %%
# making the query into a df

import pandas as pd

summer_audiofeat = pd.DataFrame(sp.audio_features(tracks= tracks))
summer_audiofeat
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.634   0.285    9   -14.007     0       0.0807      0.937000
# 1          0.762   0.701    8    -3.541     1       0.0286      0.235000
# 2          0.702   0.825    6    -3.787     0       0.0601      0.008830
# 3          0.610   0.508    8    -6.682     0       0.1520      0.297000
# 4          0.650   0.825    0    -4.645     1       0.0325      0.021500
# 5          0.677   0.696    0    -6.181     1       0.1190      0.321000
# 6          0.655   0.469    0    -6.257     1       0.0292      0.173000
# 7          0.789   0.536    6    -6.862     1       0.2420      0.410000
# 8          0.778   0.695    4    -6.865     0       0.0913      0.175000
# 9          0.841   0.593    1    -7.846     1       0.0379      0.418000
# 10         0.443   0.459    0    -8.955     1       0.0740      0.546000
# 11         0.586   0.616    5    -7.964     1       0.0324      0.182000
# ...

# %%
summer_audiofeat.to_csv('audiofeatures_summer_playlist_tracks.csv')

# %%
summer_playlists
# Out:
# ['37i9dQZF1DWZKxDdpAkEjR',
#  '37i9dQZF1DWSf2RDTDayIx',
#  '37i9dQZF1DXb54TOYHv7Df',
#  '37i9dQZF1DWYAcBZSAVhlf',
#  '37i9dQZF1DX83I5je4W4rP',
#  '37i9dQZF1DWZg863fGtALu',
#  '37i9dQZF1DX5Ozry5U6G0d',
#  '37i9dQZF1DX6aqIZNmXBGU',
#  '37i9dQZF1DX4psg7TSYpot',
#  '37i9dQZF1DX6ALfRKlHn1t',
#  '37i9dQZF1DWWsGacA3f5kN',
#  '37i9dQZF1DXbHKTQ2s1l8q',
#  '37i9dQZF1DWZSdcRHMl2tT',
#  '37i9dQZF1DWTKxc7ZObqeH',
#  '37i9dQZF1DXbwoaqxaoAVr',
#  '37i9dQZF1DWVAArCxuIRGQ',
#  '37i9dQZF1DWUajed02NzWR',
#  '37i9dQZF1DXa8n42306eJB',
#  '37i9dQZF1DX44AF5xq04Oh',
#  '37i9dQZF1DWYRUctuBGBo1']

# %%
#function für 1 playlist
#retunr wert alle track ids

# wenn function da, dann kann ich die über die playlist ids loopen und jedem loop die function si
# ergebnis append zu en track ids

# %%
# song list
songs = [i for i in range(1,320)]

def chunks(lst, n):
    """Yield successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

        
audio_feats = []
for chunk in list(chunks(songs, 50)):
        audio_feats.append(sp.audio_features(chunk))
